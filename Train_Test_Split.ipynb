# %%
# import needed libraries

import numpy as np
import pandas as pd

# %%
# Data Onboarding

from google.colab import files
data = files.upload()
# Out:
#      <input type="file" id="files-b934eb2f-943e-45e0-8532-e6c8d8d580a4" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b934eb2f-943e-45e0-8532-e6c8d8d580a4">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Data Frame

df = pd.read_excel('sample 1 (1).xlsx')

# %%
# Shallow copy

shlw=df.copy()

# %%
df
# Out:
#       age            job   marital  education default  balance housing loan  \
# 0      58     management   married   tertiary      no     2143     yes   no
# 1      44     technician    single  secondary      no       29     yes   no
# 2      33   entrepreneur   married  secondary      no        2     yes  yes
# 3      47    blue-collar   married    unknown      no     1506     yes   no
# 4      33        unknown    single    unknown      no        1      no   no
# ...   ...            ...       ...        ...     ...      ...     ...  ...
# 8994   54  self-employed   married  secondary      no      153     yes   no
# 8995   59         admin.    single  secondary      no      848      no   no
# 8996   59        retired   married  secondary      no       56      no   no
# 8997   37     technician  divorced  secondary     yes      325     yes  yes
# 8998   40     management    single   tertiary      no     -222     yes   no
#
# ...

# %% [markdown]
# ***Exploratory Data Analysis***

# %%
# It returns the shape of the dataset with rows and columns.

df.shape
# Out:
# (8999, 17)

# %%
# It returns the first five records by default.Based on user give the parameter it will be change.

df.head()
# Out:
#    age           job  marital  education default  balance housing loan  \
# 0   58    management  married   tertiary      no     2143     yes   no
# 1   44    technician   single  secondary      no       29     yes   no
# 2   33  entrepreneur  married  secondary      no        2     yes  yes
# 3   47   blue-collar  married    unknown      no     1506     yes   no
# 4   33       unknown   single    unknown      no        1      no   no
#
#    contact  day month  duration  campaign  pdays  previous poutcome   y
# 0  unknown    5   may       261         1     -1         0  unknown  no
# 1  unknown    5   may       151         1     -1         0  unknown  no
# 2  unknown    5   may        76         1     -1         0  unknown  no
# 3  unknown    5   may        92         1     -1         0  unknown  no
# 4  unknown    5   may       198         1     -1         0  unknown  no

# %%
# It returns the last five records by default.Based on user give the parameter it will be change.

df.tail()
# Out:
#       age            job   marital  education default  balance housing loan  \
# 8994   54  self-employed   married  secondary      no      153     yes   no
# 8995   59         admin.    single  secondary      no      848      no   no
# 8996   59        retired   married  secondary      no       56      no   no
# 8997   37     technician  divorced  secondary     yes      325     yes  yes
# 8998   40     management    single   tertiary      no     -222     yes   no
#
#       contact  day month  duration  campaign  pdays  previous poutcome   y
# 8994  unknown    5   jun        40         1     -1         0  unknown  no
# 8995  unknown    5   jun        63         1     -1         0  unknown  no
# 8996  unknown    5   jun       396         1     -1         0  unknown  no
# 8997  unknown    5   jun       487         1     -1         0  unknown  no
# 8998  unknown    5   jun       221         1     -1         0  unknown  no

# %%
# It will display the use needed record.

df.iloc[20:26,:]
# Out:
#     age          job  marital  education default  balance housing loan  \
# 20   28  blue-collar  married  secondary      no      723     yes  yes
# 21   56   management  married   tertiary      no      779     yes   no
# 22   32  blue-collar   single    primary      no       23     yes  yes
# 23   25     services  married  secondary      no       50     yes   no
# 24   40      retired  married    primary      no        0     yes  yes
# 25   44       admin.  married  secondary      no     -372     yes   no
#
#     contact  day month  duration  campaign  pdays  previous poutcome   y
# 20  unknown    5   may       262         1     -1         0  unknown  no
# 21  unknown    5   may       164         1     -1         0  unknown  no
# 22  unknown    5   may       160         1     -1         0  unknown  no
# 23  unknown    5   may       342         1     -1         0  unknown  no
# 24  unknown    5   may       181         1     -1         0  unknown  no
# ...

# %%
# technical enquiry of the dataframe(check the data type for each and every column).

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8999 entries, 0 to 8998
# Data columns (total 17 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        8999 non-null   int64
#  1   job        8999 non-null   object
#  2   marital    8999 non-null   object
#  3   education  8999 non-null   object
#  4   default    8999 non-null   object
#  5   balance    8999 non-null   int64
#  6   housing    8999 non-null   object
#  7   loan       8999 non-null   object
#  8   contact    8999 non-null   object
#  9   day        8999 non-null   int64
#  10  month      8999 non-null   object
#  11  duration   8999 non-null   int64
#  12  campaign   8999 non-null   int64
#  13  pdays      8999 non-null   int64
#  14  previous   8999 non-null   int64
#  15  poutcome   8999 non-null   object
#  16  y          8999 non-null   object
# dtypes: int64(7), object(10)
# memory usage: 1.2+ MB

# %%
# Mini Statistical report.

df.describe()
# Out:
#                age       balance          day     duration     campaign  \
# count  8999.000000   8999.000000  8999.000000  8999.000000  8999.000000
# mean     39.221802   1035.636182    16.007779   263.822425     2.614735
# std       9.248534   2491.982770     9.027418   248.995703     2.955875
# min      20.000000  -3372.000000     2.000000     0.000000     1.000000
# 25%      32.000000     39.000000     8.000000   116.000000     1.000000
# 50%      38.000000    332.000000    15.000000   192.000000     2.000000
# 75%      46.000000   1053.000000    26.000000   322.000000     3.000000
# max      61.000000  58544.000000    30.000000  3366.000000    63.000000
#
#         pdays  previous
# count  8999.0    8999.0
# mean     -1.0       0.0
# std       0.0       0.0
# min      -1.0       0.0
# 25%      -1.0       0.0
# 50%      -1.0       0.0
# 75%      -1.0       0.0
# max      -1.0       0.0

# %%
# it will identify the null value of the column.

df.isnull().sum()
# Out:
# age          0
# job          0
# marital      0
# education    0
# default      0
# balance      0
# housing      0
# loan         0
# contact      0
# day          0
# month        0
# duration     0
# campaign     0
# pdays        0
# previous     0
# poutcome     0
# y            0
# dtype: int64

# %% [markdown]
# ***Here the above scenario isnull function says our dataset have '0' null but we saw the dataset some features values are 'unknown'.So, here what we known is the data collection team is missing the feature value. So, we handling the missing values to that features.***

# %%
# It returns the unique value in given column

df['previous'].unique()
# Out:
# array([0])

# %%
df['poutcome'].unique()
# Out:
# array(['unknown'], dtype=object)

# %%
df['contact'].unique()
# Out:
# array(['unknown'], dtype=object)

# %% [markdown]
# ***Here the 'unknown' values features are 'contact' and 'poutcome'.This type of we can't replace the random values.Because contact number are personal and different to each other that same as poutcome.So we drop those features from our dataset.***

# %%
# drop the contact feature

df=df.drop(['contact'],axis=1)

# %%
# drop the poutcome feature

df=df.drop(['poutcome'],axis=1)

# %% [markdown]
# # ***X_Y SPLIT***

# %%
# Here we split X_data / Independent feature and Y_data / depentent feature.

x=df.iloc[:,:-1]
y=df.iloc[:,-1]

# %%
x
# Out:
#       age            job   marital  education default  balance housing loan  \
# 0      58     management   married   tertiary      no     2143     yes   no
# 1      44     technician    single  secondary      no       29     yes   no
# 2      33   entrepreneur   married  secondary      no        2     yes  yes
# 3      47    blue-collar   married    unknown      no     1506     yes   no
# 4      33        unknown    single    unknown      no        1      no   no
# ...   ...            ...       ...        ...     ...      ...     ...  ...
# 8994   54  self-employed   married  secondary      no      153     yes   no
# 8995   59         admin.    single  secondary      no      848      no   no
# 8996   59        retired   married  secondary      no       56      no   no
# 8997   37     technician  divorced  secondary     yes      325     yes  yes
# 8998   40     management    single   tertiary      no     -222     yes   no
#
#       day month  duration  campaign  pdays  previous
# ...

# %%
y
# Out:
# 0       no
# 1       no
# 2       no
# 3       no
# 4       no
#         ..
# 8994    no
# 8995    no
# 8996    no
# 8997    no
# 8998    no
# Name: y, Length: 8999, dtype: object

# %% [markdown]
# # ***Train_Test_Split***

# %%
# Here we split X_variable into X_train and X_test and then Y_variable into Y_train and Y_test.

from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=42)

                                                          # Here we give the test_size=? or_else train_size=?
                                                        # test_size must be  test_size=0.3 or 0.25 or 0.20
                                                        # train_size must be  train_size=0.7 or 0.75 or 0.80
